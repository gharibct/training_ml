# %% [markdown]
# <a href="https://colab.research.google.com/github/gharibct/training_ml/blob/dev/01_data_preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
